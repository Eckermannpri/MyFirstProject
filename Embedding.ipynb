# %% [markdown]
# <a href="https://colab.research.google.com/github/Eckermannpri/MyFirstProject/blob/main/Embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importações e configurações iniciais
import numpy as np
import pandas as pd
import google.generativeai as genai

GOOGLE_API_KEY = "GOOGLE_API_KEY"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
    if 'embedContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
#Exemplo de embedding
title = "A próxima geração IA"
sample_text = ("A próxima geração IA"
  "\n"
  "Artigo completo:\n"
  "\n"
  "Gemini API & Google AI Studio"
  )

embeddings = genai.embed_content(model="models/embedding-001",
                                 content=sample_text,
                                 title=title,
                                 task_type="RETRIEVAL_DOCUMENT")
print(embeddings)
# Out:
# {'embedding': [0.035171892, -0.025328133, -0.012429673, -0.019631244, 0.06957111, -0.009605557, -0.018776255, -0.02066997, 0.052745447, 0.059609655, -0.00026317633, 0.038690966, -0.035290744, -0.007183434, 0.011420136, -0.032057825, 0.014450685, 0.005102648, -0.030116348, 0.011583537, -0.0069046374, -0.0020109673, -0.013582597, -0.03723193, -0.01854737, 0.012639789, 0.005878598, -0.02938648, -0.03670793, 0.014274852, -0.037487585, 0.059599258, -0.034396816, 0.004073101, -0.018168556, -0.07880987, -0.033200283, -0.055943742, 0.008247926, 0.0019186451, 0.015891466, -0.08280964, -3.928563e-06, 0.009787912, -0.0005969717, -0.038131762, 0.013959166, 0.045688156, 0.031512793, -0.0672928, 0.048516978, 0.03299041, 0.078610756, -0.038307734, -0.011291569, 0.005314996, 0.053961042, -0.040603027, 0.022815498, 0.012039996, 0.015561319, 0.01262013, -0.023180014, 0.052973326, 0.002043878, -0.04751636, -0.03325974, -0.00034410378, 0.024662869, 0.021170953, 0.0300707, 0.0049784873, 0.074756846, -0.0
# ...

# %%
#Listagem de documentos que serão buscados
DOCUMENT1 = {
    "Título" : "Operação do sistema",
    "Conteúdo" : "O googlecar tem um sistema de controle climático"
}
DOCUMENT2 = {
    "Título" : "Touchscrenn",
    "Conteúdo" : "O seu googlecar tem uma grande tela sensível"
}
DOCUMENT3 = {
    "Título" : "Mudança de marchas",
    "Conteúdo" : "O seu googlecar tem uma transmissão automática"
}
documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

# %%
df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df
# Out:
#                 Titulo                                          Conteudo
# 0  Operação do sistema  O googlecar tem um sistema de controle climático
# 1          Touchscrenn      O seu googlecar tem uma grande tela sensível
# 2   Mudança de marchas    O seu googlecar tem uma transmissão automática
